# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.plot?

# %%
plt.plot(5,5, "o")
plt.show()

# %%
plt.xlabel("dane na osi X")
# Out:
# Text(0.5, 0, 'dane na osi X')

# %%
# %matplotlib notebook

# %%
plt.plot(6,6, "o")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.xlabel("dane na nowej osi x ")
plt.ylabel("dane na osi Y")
# Out:
# Text(0, 0.5, 'dane na osi Y')

# %%
import pandas as pd

# %%
df1 = pd.read_excel("canada.xlsx")

# %%
df1
# Out:
#               Unnamed: 0  Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0                    NaN         NaN        NaN        NaN        NaN
# 1                    NaN         NaN        NaN        NaN        NaN
# 2                    NaN         NaN        NaN        NaN        NaN
# 3         United Nations         NaN        NaN        NaN        NaN
# 4    Population Division         NaN        NaN        NaN        NaN
# ..                   ...         ...        ...        ...        ...
# 212           Immigrants  Foreigners      Yemen        935       Asia
# 213           Immigrants  Foreigners     Zambia        903     Africa
# 214           Immigrants  Foreigners   Zimbabwe        903     Africa
# 215           Immigrants  Foreigners    Unknown        999      World
# 216           Immigrants        Both      Total        999      World
#
#     Unnamed: 5      Unnamed: 6 Unnamed: 7          Unnamed: 8  Unnamed: 9  \
# ...

# %%
df_cleaned = df1.drop(range(19) ,axis=0)

# %%
df_cleaned
# Out:
#      Unnamed: 0  Unnamed: 1      Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 19         Type    Coverage          OdName       AREA   AreaName        REG
# 20   Immigrants  Foreigners     Afghanistan        935       Asia       5501
# 21   Immigrants  Foreigners         Albania        908     Europe        925
# 22   Immigrants  Foreigners         Algeria        903     Africa        912
# 23   Immigrants  Foreigners  American Samoa        909    Oceania        957
# ..          ...         ...             ...        ...        ...        ...
# 212  Immigrants  Foreigners           Yemen        935       Asia        922
# 213  Immigrants  Foreigners          Zambia        903     Africa        910
# 214  Immigrants  Foreigners        Zimbabwe        903     Africa        910
# 215  Immigrants  Foreigners         Unknown        999      World        999
# 216  Immigrants        Both           Total        999      World        999
#
# ...

# %%
df_cleaned.reset_index(inplace = True, drop=True)

# %%
df_cleaned
# Out:
#      index  Unnamed: 0  Unnamed: 1      Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0       19        Type    Coverage          OdName       AREA   AreaName
# 1       20  Immigrants  Foreigners     Afghanistan        935       Asia
# 2       21  Immigrants  Foreigners         Albania        908     Europe
# 3       22  Immigrants  Foreigners         Algeria        903     Africa
# 4       23  Immigrants  Foreigners  American Samoa        909    Oceania
# ..     ...         ...         ...             ...        ...        ...
# 193    212  Immigrants  Foreigners           Yemen        935       Asia
# 194    213  Immigrants  Foreigners          Zambia        903     Africa
# 195    214  Immigrants  Foreigners        Zimbabwe        903     Africa
# 196    215  Immigrants  Foreigners         Unknown        999      World
# 197    216  Immigrants        Both           Total        999      World
#
#     Unnamed: 5       Unnamed: 6 Unnamed: 7          Unnamed: 8  ...  \
# ...

# %%
df_cleaned.drop(labels="index", axis=1, inplace=True)

# %%
df_cleaned
# Out:
#      Unnamed: 0  Unnamed: 1      Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0          Type    Coverage          OdName       AREA   AreaName        REG
# 1    Immigrants  Foreigners     Afghanistan        935       Asia       5501
# 2    Immigrants  Foreigners         Albania        908     Europe        925
# 3    Immigrants  Foreigners         Algeria        903     Africa        912
# 4    Immigrants  Foreigners  American Samoa        909    Oceania        957
# ..          ...         ...             ...        ...        ...        ...
# 193  Immigrants  Foreigners           Yemen        935       Asia        922
# 194  Immigrants  Foreigners          Zambia        903     Africa        910
# 195  Immigrants  Foreigners        Zimbabwe        903     Africa        910
# 196  Immigrants  Foreigners         Unknown        999      World        999
# 197  Immigrants        Both           Total        999      World        999
#
# ...

# %%
old_clomn_names = df_cleaned.keys()

# %%
type(old_clomn_names)
# Out:
# pandas.core.indexes.base.Index

# %%
new_column_names = df_cleaned.iloc[0]

# %%
df_cleaned.head(1)
# Out:
#   Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0       Type   Coverage     OdName       AREA   AreaName        REG
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8  Unnamed: 9  ...  Unnamed: 33  Unnamed: 34  \
# 0    RegName        DEV    DevName      1980.0  ...       2004.0       2005.0
#
#    Unnamed: 35  Unnamed: 36  Unnamed: 37  Unnamed: 38  Unnamed: 39  \
# 0       2006.0       2007.0       2008.0       2009.0       2010.0
#
#    Unnamed: 40  Unnamed: 41  Unnamed: 42
# 0       2011.0       2012.0       2013.0
#
# [1 rows x 43 columns]

# %%
new_column_names
# Out:
# Unnamed: 0         Type
# Unnamed: 1     Coverage
# Unnamed: 2       OdName
# Unnamed: 3         AREA
# Unnamed: 4     AreaName
# Unnamed: 5          REG
# Unnamed: 6      RegName
# Unnamed: 7          DEV
# Unnamed: 8      DevName
# Unnamed: 9       1980.0
# Unnamed: 10      1981.0
# Unnamed: 11      1982.0
# Unnamed: 12      1983.0
# Unnamed: 13      1984.0
# Unnamed: 14      1985.0
# Unnamed: 15      1986.0
# Unnamed: 16      1987.0
# Unnamed: 17      1988.0
# Unnamed: 18      1989.0
# Unnamed: 19      1990.0
# Unnamed: 20      1991.0
# Unnamed: 21      1992.0
# Unnamed: 22      1993.0
# Unnamed: 23      1994.0
# Unnamed: 24      1995.0
# Unnamed: 25      1996.0
# Unnamed: 26      1997.0
# Unnamed: 27      1998.0
# Unnamed: 28      1999.0
# Unnamed: 29      2000.0
# Unnamed: 30      2001.0
# Unnamed: 31      2002.0
# Unnamed: 32      2003.0
# Unnamed: 33      2004.0
# Unnamed: 34      2005.0
# Unnamed: 35      2006.0
# Unnamed: 36      2007.0
# Unnamed: 37      2008.0
# ...

# %%
df_cleaned.iloc[0]
# Out:
# Unnamed: 0         Type
# Unnamed: 1     Coverage
# Unnamed: 2       OdName
# Unnamed: 3         AREA
# Unnamed: 4     AreaName
# Unnamed: 5          REG
# Unnamed: 6      RegName
# Unnamed: 7          DEV
# Unnamed: 8      DevName
# Unnamed: 9       1980.0
# Unnamed: 10      1981.0
# Unnamed: 11      1982.0
# Unnamed: 12      1983.0
# Unnamed: 13      1984.0
# Unnamed: 14      1985.0
# Unnamed: 15      1986.0
# Unnamed: 16      1987.0
# Unnamed: 17      1988.0
# Unnamed: 18      1989.0
# Unnamed: 19      1990.0
# Unnamed: 20      1991.0
# Unnamed: 21      1992.0
# Unnamed: 22      1993.0
# Unnamed: 23      1994.0
# Unnamed: 24      1995.0
# Unnamed: 25      1996.0
# Unnamed: 26      1997.0
# Unnamed: 27      1998.0
# Unnamed: 28      1999.0
# Unnamed: 29      2000.0
# Unnamed: 30      2001.0
# Unnamed: 31      2002.0
# Unnamed: 32      2003.0
# Unnamed: 33      2004.0
# Unnamed: 34      2005.0
# Unnamed: 35      2006.0
# Unnamed: 36      2007.0
# Unnamed: 37      2008.0
# ...
