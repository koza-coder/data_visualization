# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
dane1 = np.random.randn?

# %%
dane1 = np.random.randn(10000)

# %%
dane1
# Out:
# array([-0.68880073,  0.25085697, -0.17086749, ..., -2.25264141,
#         1.99439367, -0.36482109])

# %%
dane1.shape
# Out:
# (10000,)

# %%
plt.hist?

# %%
plt.hist(dane1, 100)
plt.title(r"normal distribution with $\mu=0, sigma=1$")
plt.savefig("wykres1.png")
plt.show()
